# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.csv')

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
data.isnull().any() #checking for any missing value
# Out:
# customerID          False
# gender              False
# SeniorCitizen       False
# Partner             False
# Dependents          False
# tenure              False
# PhoneService        False
# MultipleLines       False
# InternetService     False
# OnlineSecurity      False
# OnlineBackup        False
# DeviceProtection    False
# TechSupport         False
# StreamingTV         False
# StreamingMovies     False
# Contract            False
# PaperlessBilling    False
# PaymentMethod       False
# MonthlyCharges      False
# TotalCharges        False
# Churn               False
# dtype: bool

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
# customerID          7043 non-null object
# gender              7043 non-null object
# SeniorCitizen       7043 non-null int64
# Partner             7043 non-null object
# Dependents          7043 non-null object
# tenure              7043 non-null int64
# PhoneService        7043 non-null object
# MultipleLines       7043 non-null object
# InternetService     7043 non-null object
# OnlineSecurity      7043 non-null object
# OnlineBackup        7043 non-null object
# DeviceProtection    7043 non-null object
# TechSupport         7043 non-null object
# StreamingTV         7043 non-null object
# StreamingMovies     7043 non-null object
# Contract            7043 non-null object
# PaperlessBilling    7043 non-null object
# PaymentMethod       7043 non-null object
# MonthlyCharges      7043 non-null float64
# TotalCharges        7043 non-null object
# ...

# %%
data['Churn'].value_counts() #classifying customers if they churned or not
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
sns.countplot(data['Churn'])

# %%
data['SeniorCitizen'].sum()
# Out:
# 1142

# %% [markdown]
# Total number of senior citizens in the dataset :- 1142

# %%
(data['SeniorCitizen']==0).value_counts()
# Out:
# True     5901
# False    1142
# Name: SeniorCitizen, dtype: int64

# %% [markdown]
# Total number of citizens who are not senior citizens :- 5901

# %%
pd.crosstab(data.Churn, data.SeniorCitizen,margins=True)
# Out:
# SeniorCitizen     0     1   All
# Churn
# No             4508   666  5174
# Yes            1393   476  1869
# All            5901  1142  7043

# %%
data[data['gender']=='Female'].shape
# Out:
# (3488, 21)

# %% [markdown]
# Total Female Customers :- 3488

# %%
data[data['gender']=='Male'].shape
# Out:
# (3555, 21)

# %% [markdown]
# Total Male Customers :- 3555

# %%
sns.countplot(data['gender'],hue=data['Churn'])

# %% [markdown]
# Based on gender , Male customers are slightly less likely to end there subscription.

# %%
sns.countplot(data['SeniorCitizen'],hue=data['Churn'])

# %% [markdown]
# Senior citizens have a much worse churn ratio compared to normal citizens.

# %%
sns.countplot(data['InternetService'])

# %%
sns.countplot(data['InternetService'] , hue=data['Churn'])

# %% [markdown]
# Both of these bar plots clearly show us that although Fiber optic is the most used internet service but it's churn ratio is the worst.

# %%
plt.figure(figsize=(15,4))
sns.countplot(data['PaymentMethod'])

# %%
plt.figure(figsize=(15,4))
sns.countplot(data['PaymentMethod'] , hue=data['Churn'])

# %% [markdown]
# Again Electronic check is the most used payment method but has the worst churn ratios amongst other payment methods.

# %%
sns.countplot(data['PaperlessBilling'])

# %% [markdown]
# Paperless Billing is the more preferred payment option.

# %%
sns.countplot(data['PaperlessBilling'] , hue=data['Churn'])

# %%
data['Contract'].unique()
# Out:
# array(['Month-to-month', 'One year', 'Two year'], dtype=object)

# %%
sns.countplot(data['Contract'])

# %% [markdown]
# Most customers have the month-to-month plan.

# %%
sns.countplot(data['Contract'] , hue=data['Churn'])

# %% [markdown]
# Customers who take the two year plan are less likely to churn.

# %%
sns.countplot(data['StreamingMovies'])

# %%
sns.countplot(data['StreamingMovies'],hue=data['Churn'])

# %%
sns.countplot(data['StreamingTV'])

# %%
sns.countplot(data['StreamingTV'],hue=data['Churn'])

# %%
data['MultipleLines'].unique()
# Out:
# array(['No phone service', 'No', 'Yes'], dtype=object)

# %%
sns.countplot(data['MultipleLines'])

# %%
sns.countplot(data['MultipleLines'],hue=data['Churn'])

# %% [markdown]
# Customers who don't have multiple lines are less likely to end subscription.

# %%
y = data['Churn']
x = data['tenure']
sns.barplot(x,y)

# %% [markdown]
# Customers having tenure more than 17 are less likely to end subscription.

# %%
y = data['Churn']
x = data['MonthlyCharges']
sns.barplot(x,y,data=data)

# %%
sns.lineplot(data['tenure'],data['MonthlyCharges'],data=data)

# %%
data.groupby('Contract')['customerID'].count()
# Out:
# Contract
# Month-to-month    3875
# One year          1473
# Two year          1695
# Name: customerID, dtype: int64

# %%
y=data.groupby('PaymentMethod')['customerID'].count()

# %%
sns.catplot(x='Churn',y='tenure',kind='swarm',data=data)

# %% [markdown]
# Customers with tenure more than 40 are less likely to end subscription.

# %%
sns.kdeplot(data['MonthlyCharges'],shade=True)

# %% [markdown]
# Most customers have monthly charges around 20 or near 80.

# %%
sns.countplot(data['DeviceProtection'])

# %% [markdown]
# Majority of the customers don't have device protection.

# %%
sns.countplot(data['DeviceProtection'],hue=data['Churn'])

# %% [markdown]
# Customers who don't have device protection end subscription more than the others.

# %%
sns.countplot(data['TechSupport'])

# %%
sns.countplot(data['TechSupport'],hue=data['Churn'])

# %% [markdown]
#     Majority of the customers who don't have technical support end subscription more than others.

# %%
sns.countplot(data['OnlineBackup'])

# %%
sns.countplot(data['OnlineBackup'],hue=data['Churn'])

# %% [markdown]
# Customers with no online backup are more likely to end the subscription.

# %%
sns.countplot(data['OnlineSecurity'])

# %%
sns.countplot(data['OnlineSecurity'],hue=data['Churn'])

# %% [markdown]
# Customers having no online security have more people who end the subsciption.

# %%
sns.countplot(data['Partner'],hue=data['Churn'])

# %% [markdown]
# Clearly , if you are a partner you are less likely to end subscription.

# %%
data['TotalCharges'] = data['TotalCharges'].replace(" ", 0).astype('float32')

# %%
sns.scatterplot(data['MonthlyCharges'],data['TotalCharges'])

# %%
sns.scatterplot(data['tenure'],data['TotalCharges'])

# %%
sns.countplot(data['Dependents'])

# %%
sns.countplot(data['Dependents'],hue=data['Churn'])

# %% [markdown]
# Customers without dependents are also more likely to churn
